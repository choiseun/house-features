# %% [markdown]
# ### Jake's Kaggle Submission Walkthrough

# %%
# Imports
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures, StandardScaler

# %%
# Read in data
df = pd.read_csv('../datasets/train.csv')
kaggle_sub_data = pd.read_csv('../datasets/test.csv')

# %%
df.head(3)
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
#
#   Lot Shape Land Contour  ... Screen Porch Pool Area Pool QC Fence  \
# 0       IR1          Lvl  ...            0         0     NaN   NaN
# 1       IR1          Lvl  ...            0         0     NaN   NaN
# 2       Reg          Lvl  ...            0         0     NaN   NaN
#
#   Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  SalePrice
# 0          NaN        0       3    2010        WD      130500
# 1          NaN        0       4    2009        WD      220000
# 2          NaN        0       1    2010        WD      109000
#
# [3 rows x 81 columns]

# %%
# Rename columns
df.columns = [column.replace(' ','_').lower() for column in df.columns]

# %%
df.head(3)
# Out:
#     id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
#
#   lot_shape land_contour  ... screen_porch pool_area pool_qc fence  \
# 0       IR1          Lvl  ...            0         0     NaN   NaN
# 1       IR1          Lvl  ...            0         0     NaN   NaN
# 2       Reg          Lvl  ...            0         0     NaN   NaN
#
#   misc_feature misc_val mo_sold yr_sold  sale_type  saleprice
# 0          NaN        0       3    2010        WD      130500
# 1          NaN        0       4    2009        WD      220000
# 2          NaN        0       1    2010        WD      109000
#
# [3 rows x 81 columns]

# %% [markdown]
# ### Model 1

# %%
# Jake chose features that required no EDA/data cleaning
# Define X and y
features = ['lot_area','fireplaces','1st_flr_sf','full_bath','half_bath','totrms_abvgrd']
X = df[features]
y = df['saleprice']

# Train test split
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=42)

# %%
# Instantiate linear regression model
lr_1 = LinearRegression()
lr_1.fit(X_train,y_train)
lr_1.score(X_train,y_train), lr_1.score(X_test,y_test)
# Out:
# (0.586908421365044, 0.6437361531661306)

# %%
# Make predictions from Kaggle test data - ERROR MESSAGE!!!
kaggle_preds = lr_1.predict(kaggle_sub_data[features])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-9401bb2f62e1> in <module>
#       1 # Make predictions from Kaggle test data
# ----> 2 kaggle_preds = lr_1.predict(kaggle_sub_data[features])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1296             if missing == len(indexer):
#    1297                 axis_name = self.obj._get_axis_name(axis)
# -> 1298                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1299
#    1300             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [
#         93978.92536412, 180559.4131222 , 170265.96618369, 210193.78585339,
#         98735.05236818, 147839.34677922, 199424.50330359, 150155.37702462,
#        193330.40556011,  75421.40989658, 187448.10661885,  99639.93226164,
#        306552.84940308,  90423.80236311, 137280.04667647, 201352.50594093,
#        212460.97553907, 180482.87544708, 222504.17674959, 193796.64461856,
#        342194.47238058, 210699.91681533, 226200.86429372, 306042.35296015,
#        192874.27345506, 228869.86464247, 234371.43911217, 152430.71721397,
#        102242.55356921, 149824.48510534])

# %%
# Assign kaggle_preds to 'saleprice' column (absent in test csv)
kaggle_sub_data['saleprice'] = kaggle_preds

# %%
kaggle_sub_data[['id','saleprice']]
# Out:
#        id      saleprice
# 0    2658  159449.713528
# 1    2718  251304.668573
# 2    2414  190992.300403
# 3    1989  110894.990037
# 4     625  229389.162867
# ..    ...            ...
# 873  1662  228869.864642
# 874  1234  234371.439112
# 875  1373  152430.717214
# 876  1672  102242.553569
# 877  1939  149824.485105
#
# [878 rows x 2 columns]

# %%
# Save as csv file
kaggle_sub_data[['id','saleprice']].to_csv('../datasets/jake_sub_1.csv',index=False)

# %% [markdown]
# ### Model 2

# %%
# Re-import test.csv just to have clean slate
kaggle_sub_data = pd.read_csv('../datasets/test.csv')

# %%
# Need to make column names the same in training and testing dataframes
kaggle_sub_data.columns = [column.replace(' ','_').lower() for column in kaggle_sub_data.columns]

# %%
# Define X and y
features = ['lot_area','fireplaces','1st_flr_sf','full_bath','half_bath','totrms_abvgrd']
X = df[features]
y = df['saleprice']

# Train test split
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=42)

# %%
# Instantiate PolyFeat
poly = PolynomialFeatures(include_bias=False)

# Fit the Poly
poly.fit(X_train)
# Out:
# PolynomialFeatures(include_bias=False)

# %%
# Transform the Poly
X_train_pf = poly.transform(X_train)
X_test_pf = poly.transform(X_test)

# %%
# View what happened as a dataframe - now have 27 columns 
# Important!! how to view PolyFeatures
pd.DataFrame(X_train_pf,columns=poly.get_feature_names(X.columns))
# Out:
#       lot_area  fireplaces  1st_flr_sf  full_bath  half_bath  totrms_abvgrd  \
# 0      10667.0         1.0      1587.0        2.0        0.0            7.0
# 1      12888.0         2.0      1262.0        1.0        1.0            7.0
# 2       7200.0         0.0       864.0        1.0        0.0            5.0
# 3      14000.0         0.0      1306.0        2.0        1.0            7.0
# 4      11929.0         1.0      1251.0        2.0        1.0            9.0
# ...        ...         ...         ...        ...        ...            ...
# 1533    9709.0         2.0       958.0        2.0        1.0            8.0
# 1534    9000.0         1.0      1196.0        1.0        0.0            6.0
# 1535   10140.0         1.0      1309.0        1.0        1.0            5.0
# 1536    1869.0         0.0       483.0        1.0        1.0            5.0
# 1537    9100.0         0.0      1525.0        2.0        0.0            6.0
#
#        lot_area^2  lot_area fireplaces  lot_area 1st_flr_sf  \
# 0     113784889.0              10667.0           16928529.0
# 1     166100544.0              25776.0           16264656.0
# 2      51840000.0                  0.0            6220800.0
# 3     196000000.0                  0.0           18284000.0
# 4     142301041.0              11929.0           14923179.0
# ...           ...                  ...                  ...
# 1533   94264681.0              19418.0            9301222.0
# 1534   81000000.0               9000.0           10764000.0
# 1535  102819600.0              10140.0           13273260.0
# 1536    3493161.0                  0.0             902727.0
# 1537   82810000.0                  0.0           13877500.0
#
#       lot_area full_bath  ...  1st_flr_sf^2  1st_flr_sf full_bath  \
# 0                21334.0  ...     2518569.0                3174.0
# 1                12888.0  ...     1592644.0                1262.0
# 2                 7200.0  ...      746496.0                 864.0
# 3                28000.0  ...     1705636.0                2612.0
# 4                23858.0  ...     1565001.0                2502.0
# ...                  ...  ...           ...                   ...
# 1533             19418.0  ...      917764.0                1916.0
# 1534              9000.0  ...     1430416.0                1196.0
# 1535             10140.0  ...     1713481.0                1309.0
# 1536              1869.0  ...      233289.0                 483.0
# 1537             18200.0  ...     2325625.0                3050.0
#
#       1st_flr_sf half_bath  1st_flr_sf totrms_abvgrd  full_bath^2  \
# 0                      0.0                   11109.0          4.0
# 1                   1262.0                    8834.0          1.0
# 2                      0.0                    4320.0          1.0
# 3                   1306.0                    9142.0          4.0
# 4                   1251.0                   11259.0          4.0
# ...                    ...                       ...          ...
# 1533                 958.0                    7664.0          4.0
# 1534                   0.0                    7176.0          1.0
# 1535                1309.0                    6545.0          1.0
# 1536                 483.0                    2415.0          1.0
# 1537                   0.0                    9150.0          4.0
#
#       full_bath half_bath  full_bath totrms_abvgrd  half_bath^2  \
# 0                     0.0                     14.0          0.0
# 1                     1.0                      7.0          1.0
# 2                     0.0                      5.0          0.0
# 3                     2.0                     14.0          1.0
# 4                     2.0                     18.0          1.0
# ...                   ...                      ...          ...
# 1533                  2.0                     16.0          1.0
# 1534                  0.0                      6.0          0.0
# 1535                  1.0                      5.0          1.0
# 1536                  1.0                      5.0          1.0
# 1537                  0.0                     12.0          0.0
#
#       half_bath totrms_abvgrd  totrms_abvgrd^2
# 0                         0.0             49.0
# 1                         7.0             49.0
# 2                         0.0             25.0
# 3                         7.0             49.0
# 4                         9.0             81.0
# ...                       ...              ...
# 1533                      8.0             64.0
# 1534                      0.0             36.0
# 1535                      5.0             25.0
# 1536                      5.0             25.0
# 1537                      0.0             36.0
#
# [1538 rows x 27 columns]

# %%
# Modeling - instantiate and fit linear model
lr_2 = LinearRegression()
lr_2.fit(X_train_pf,y_train)
# Out:
# LinearRegression()

# %%
# Checking R-squared score
lr_2.score(X_train_pf,y_train), lr_2.score(X_test_pf,y_test)
# Out:
# (0.7005281270500114, 0.4757434483326699)

# %%
# where I got stuck last night
# kaggle_preds = lr_2.predict(kaggle_test_subset)

# %%
# Poly transform kaggle test data 
kaggle_poly = poly.transform(kaggle_sub_data[features])

# Kaggle predictions
kaggle_preds = lr_2.predict(kaggle_poly)

kaggle_sub_data['saleprice'] = kaggle_preds

# %%
kaggle_sub_data[['id','saleprice']].to_csv('../datasets/jake_sub_2.csv',index=False)
